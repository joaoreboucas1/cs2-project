# %% [markdown]
# # Triangle plots for subluminal chains, dyamical $c_s^2$

# %%
import numpy as np
import getdist
from getdist import plots

import utils

# %%
indices = list(range(68, 72)) + [48]
chains = {}
for i in indices:
    chains[i] = utils.load_chain(i, burn_in=0.2, smooth_2D=0.3)

# %%
p = plots.get_subplot_plotter()
p.settings.axes_fontsize=25
p.settings.axes_labelsize=30
p.settings.legend_fontsize=30
p.triangle_plot(
    [chains[68], chains[70], chains[71], chains[48]],
    ["H0", "omegam", "S8", "w", "wa", "cs2_0", "cs2_a"],
    filled=[False, False, False, True],
    contour_colors=utils.colors[:3] + ["gray"],
    contour_lws=3,
    contour_ls=["-", "--", "-.", "-"],
    legend_labels=["$\\alpha_K \\propto \\Omega_\\mathrm{DE}$", "$\\alpha_K \\propto \\alpha_B$", "Cubic Galileon Self-Accelerating", "Fluid"],
    legend_loc="upper right",
    param_limits={"w": [-1.01, -0.55], "wa": [-1.55, 0.1], "H0": [65, 69], "omegam": [0.295, 0.34]}
)
p.fig.text(0.3, 1.01, "Data: Planck + DESI + DES-Dovekie", fontsize=20)
p.fig.savefig("plots/triangle_ds1_subluminal_dyncs2_mg.pdf", bbox_inches="tight")
# Out:
# WARNING:root:auto bandwidth for H0 very small or failed (h=0.0004093108159813308,N_eff=188.34502208467532). Using fallback (h=0.0258399079937124)
# WARNING:root:auto bandwidth for omegam very small or failed (h=0.00040481042876933424,N_eff=194.58802387578717). Using fallback (h=0.029133908211390173)
# WARNING:root:auto bandwidth for omegam very small or failed (h=0.00038947510881048446,N_eff=82.4464638296879). Using fallback (h=0.015317961877451181)
# WARNING:root:auto bandwidth for S8 very small or failed (h=0.0001569315055521875,N_eff=1999.7730275411027). Using fallback (h=0.012101274573943919)
# WARNING:root:auto bandwidth for w very small or failed (h=0.0004275105002125972,N_eff=66.04509471935992). Using fallback (h=0.012639614115492852)
# WARNING:root:auto bandwidth for wa very small or failed (h=0.0004421935465956744,N_eff=61.537794019307434). Using fallback (h=0.01353066240232929)
# WARNING:root:auto bandwidth for cs2_0 very small or failed (h=0.0004758930022749553,N_eff=135.8979434339474). Using fallback (h=0.09011636147077363)
# WARNING:root:auto bandwidth for cs2_0 very small or failed (h=0.00016422121082455265,N_eff=1638.88473587995). Using fallback (h=0.03438566824537195)
# WARNING:root:auto bandwidth for cs2_a very small or failed (h=0.0004851175737393522,N_eff=131.25786604290445). Using fallback (h=0.04475262235123883)
# WARNING:root:auto bandwidth for cs2_a very small or failed (h=0.0004584935920925641,N_eff=56.94824597220758). Using fallback (h=0.0261651400384441)
