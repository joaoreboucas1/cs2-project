# %% [markdown]
# # Triangle plots for subluminal chains, dyamical $c_s^2$

# %%
import numpy as np
import getdist
from getdist import plots

import utils

# %%
indices = list(range(68, 72)) + [48]
chains = {}
for i in indices:
    chains[i] = utils.load_chain(i, burn_in=0.2, smooth_2D=0.3)
# Out:
# ../chains/MCMC68/MCMC68.1.txt
# ../chains/MCMC68/MCMC68.2.txt
# ../chains/MCMC68/MCMC68.3.txt
# ../chains/MCMC68/MCMC68.4.txt
# Removed no burn in
# ../chains/MCMC69/MCMC69.1.txt
# ../chains/MCMC69/MCMC69.2.txt
# ../chains/MCMC69/MCMC69.3.txt
# ../chains/MCMC69/MCMC69.4.txt
# Removed no burn in
# ../chains/MCMC70/MCMC70.1.txt
# ../chains/MCMC70/MCMC70.2.txt
# ../chains/MCMC70/MCMC70.3.txt
# ../chains/MCMC70/MCMC70.4.txt
# Removed no burn in
# ../chains/MCMC71/MCMC71.1.txt
# ../chains/MCMC71/MCMC71.2.txt
# ../chains/MCMC71/MCMC71.3.txt
# ../chains/MCMC71/MCMC71.4.txt
# Removed no burn in

# %%
p = plots.get_subplot_plotter()
p.settings.axes_fontsize=25
p.settings.axes_labelsize=30
p.settings.legend_fontsize=25
p.triangle_plot(
    [chains[68], chains[70], chains[71], chains[48]],
    ["H0", "omegam", "S8", "w", "wa"],
    filled=[False, False, False, True],
    contour_colors=utils.colors[:3] + ["gray"],
    contour_lws=3,
    contour_ls=["-", "--", "-.", "-"],
    legend_labels=["$\\alpha_K \\propto \\Omega_\\mathrm{DE}$", "$\\alpha_K \\propto \\alpha_B$", "Cubic Galileon Self-Accelerating", "Fluid"],
    legend_loc="upper right",
    param_limits={"w": [-1.01, -0.55], "wa": [-1.55, 0.1], "H0": [65, 69], "omegam": [0.295, 0.34]}
)
# p.fig.text(0.3, 1.01, "Data: Planck + DESI + DES-Dovekie", fontsize=20)
p.fig.savefig("plots/triangle_ds1_subluminal_dyncs2_mg.pdf", bbox_inches="tight")
# Out:
# WARNING:root:auto bandwidth for H0 very small or failed (h=0.0004009461249710622,N_eff=277.5526619683848). Using fallback (h=0.026948492884600952)
# WARNING:root:auto bandwidth for H0 very small or failed (h=0.0001557935774222146,N_eff=4207.735342792178). Using fallback (h=0.010385876967418927)
# WARNING:root:auto bandwidth for omegam very small or failed (h=0.00041344580000251635,N_eff=259.6209866888715). Using fallback (h=0.02974726594801857)
# WARNING:root:auto bandwidth for w very small or failed (h=0.0005106089089850424,N_eff=94.80270898232547). Using fallback (h=0.024120815248353213)
# WARNING:root:auto bandwidth for wa very small or failed (h=0.0005391797475161982,N_eff=87.07030050129083). Using fallback (h=0.022174081961152003)

# %%
p = plots.get_subplot_plotter(width_inch=11, subplot_size_ratio=3/4)
p.settings.axes_fontsize=20
p.settings.axes_labelsize=20
p.settings.legend_fontsize=15
p.plots_1d(
    [chains[68], chains[69], chains[70], chains[71]],
    ["cs2_0", "cs2_a", "alpha_K_0"],
    colors=utils.colors,
    lws=3,
    ls=["-", "--", "-.", "-"],
    nx=3,
    legend_labels=["$\\alpha_K \\propto \\Omega_\\mathrm{DE}$", "K-essence-like", "$\\alpha_K \\propto \\alpha_B$", "Cubic Galileon-like"],
    legend_loc="upper right",
    legend_ncol=4,
)
p.fig.savefig("plots/lambda_mg_cs2_dyncs2_ds1.pdf", bbox_inches="tight")
# Out:
# WARNING:root:auto bandwidth for cs2_0 very small or failed (h=0.0004502784521719686,N_eff=213.68321067193628). Using fallback (h=0.09183297654769013)
# WARNING:root:auto bandwidth for cs2_0 very small or failed (h=0.00044766892039439657,N_eff=256.11792276380606). Using fallback (h=0.08680958801561928)
# WARNING:root:auto bandwidth for cs2_0 very small or failed (h=0.0007723856654227034,N_eff=25.76411032160226). Using fallback (h=0.16737685769968016)
# WARNING:root:auto bandwidth for cs2_a very small or failed (h=0.00044739666848783916,N_eff=216.18450711699637). Using fallback (h=0.04440335402475169)
# WARNING:root:auto bandwidth for cs2_a very small or failed (h=0.00042105037147858413,N_eff=292.71202048709324). Using fallback (h=0.03927664881701921)
# WARNING:root:auto bandwidth for cs2_a very small or failed (h=0.0001627341442111044,N_eff=3516.477204925931). Using fallback (h=0.026151617202075057)
# WARNING:root:auto bandwidth for alpha_K_0 very small or failed (h=0.0004417091828200587,N_eff=222.35459124558747). Using fallback (h=0.08173290282799099)
