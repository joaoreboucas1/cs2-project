# %% [markdown]
# # Triangle plots for superluminal chains, constant $c_s^2$

# %%
import numpy as np
import getdist
from getdist import plots

import utils

# %%
indices = list(range(64, 68)) + [48]
chains = {}
for i in indices:
    chains[i] = utils.load_chain(i, burn_in=0.2, smooth_2D=0.3)
# Out:
# ../chains/MCMC64/MCMC64.1.txt
# ../chains/MCMC64/MCMC64.2.txt
# ../chains/MCMC64/MCMC64.3.txt
# ../chains/MCMC64/MCMC64.4.txt
# Removed no burn in
# ../chains/MCMC65/MCMC65.1.txt
# ../chains/MCMC65/MCMC65.2.txt
# ../chains/MCMC65/MCMC65.3.txt
# ../chains/MCMC65/MCMC65.4.txt
# Removed no burn in
# ../chains/MCMC66/MCMC66.1.txt
# ../chains/MCMC66/MCMC66.2.txt
# ../chains/MCMC66/MCMC66.3.txt
# ../chains/MCMC66/MCMC66.4.txt
# Removed no burn in
# ../chains/MCMC67/MCMC67.1.txt
# ../chains/MCMC67/MCMC67.2.txt
# ../chains/MCMC67/MCMC67.3.txt
# ../chains/MCMC67/MCMC67.4.txt
# Removed no burn in

# %%
p = plots.get_subplot_plotter()
p.settings.axes_fontsize=25
p.settings.axes_labelsize=30
p.settings.legend_fontsize=30
p.triangle_plot(
    [chains[64], chains[66], chains[67], chains[48]],
    ["H0", "omegam", "S8", "w", "wa", "cs2_0", "alpha_K_0"],
    filled=[False, False, False, True],
    contour_colors=utils.colors[:3] + ["gray"],
    contour_lws=3,
    contour_ls=["-", "--", "-.", "-"],
    legend_labels=["$\\alpha_K \\propto \\Omega_\\mathrm{DE}$", "$\\alpha_K \\propto \\alpha_B$", "Cubic Galileon Self-Accelerating", "Fluid"],
    legend_loc="upper right",
    param_limits={"w": [-1.01, -0.55], "wa": [-1.55, 0.1], "H0": [65, 69], "omegam": [0.295, 0.34]}
)
p.fig.text(0.3, 1.01, "Data: Planck + DESI + DES-Dovekie", fontsize=20)
p.fig.savefig("plots/triangle_ds1_superluminal_mg.pdf", bbox_inches="tight")
# Out:
# WARNING:root:auto bandwidth for H0 very small or failed (h=0.0006072191084892575,N_eff=276.0948759700328). Using fallback (h=0.03295017303345507)
# WARNING:root:auto bandwidth for omegam very small or failed (h=0.0006167225767352402,N_eff=273.3258532508318). Using fallback (h=0.0365750652625407)
# WARNING:root:auto bandwidth for S8 very small or failed (h=0.0004481621617837742,N_eff=68.04118443072574). Using fallback (h=0.01109909023047791)
# WARNING:root:auto bandwidth for w very small or failed (h=0.00020647848537550724,N_eff=1519.3310098083048). Using fallback (h=0.03016587325752033)
# WARNING:root:auto bandwidth for wa very small or failed (h=0.00020704068642568674,N_eff=1500.4104376291589). Using fallback (h=0.032369730866019374)
# WARNING:root:auto bandwidth for cs2_0 very small or failed (h=0.0001763007745833327,N_eff=1389.4835096678976). Using fallback (h=0.02927115605635765)
# WARNING:root:auto bandwidth for cs2_0 very small or failed (h=0.0007463102844067717,N_eff=83.44604887049586). Using fallback (h=0.13328615822154005)

# %%
p = plots.get_single_plotter()
p.settings.axes_fontsize=25-10
p.settings.axes_labelsize=30-10
p.settings.legend_fontsize=30-10
p.plot_2d(
    [chains[67], chains[48]],
    ["w", "wa"],
    filled=[True, False],
    colors=[utils.colors[0], "black"],
    lws=2,
    ls=["-", "--", "-.", "-"],
    labels=["Cubic Galileon", "Fluid"],
    legend_loc="upper right",
    lims=[-1.01, -0.55, -2, 0.1]
)
p.add_x_marker(-1)
p.add_y_marker(0)
p.add_legend(["Cubic Galileon", "Fluid"], fontsize=15)
# p.fig.text(0.17, 1.01, "Data: Planck PR4 + DESI DR2 BAO + DES-Dovekie SN", fontsize=15)
p.fig.savefig("plots/triangle_ds1_superluminal_mg_w0waonly.pdf", bbox_inches="tight")
