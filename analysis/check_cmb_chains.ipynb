# %%
from importlib import reload
from copy import copy

import numpy as np
from getdist import plots as gdplot

import utils

# %%
# Load chains
settings = copy(utils.DEFAULT_GETDIST_SETTINGS)
settings['smooth_scale_2D'] = 0.4
chain = utils.load_chain(37, settings=settings)
# Out:
# ../chains/MCMC37/MCMC37.1.txt
# ../chains/MCMC37/MCMC37.2.txt
# ../chains/MCMC37/MCMC37.3.txt
# ../chains/MCMC37/MCMC37.4.txt
# Removed 0.4 as burn in

# %%
p = gdplot.get_subplot_plotter()
p.settings.axes_fontsize=25
p.settings.axes_labelsize=30
p.settings.legend_fontsize=30
p.triangle_plot(
    chain,
    ["omegam", "S8", "w", "wa", "H0"],
    filled=[True, False, False],
    contour_colors=utils.colors,
    contour_lws=3,
    contour_ls=["-", "--", "-."],
    legend_labels=["$c_s^2$ free", "$c_s^2 = 1.0$", "$c_s^2 = 0.0$"],
    legend_loc="upper right"
)
# Out:
# WARNING:root:auto bandwidth for omegam very small or failed (h=0.0002409091141091348,N_eff=2007.574375778716). Using fallback (h=0.02425774685803168)
# WARNING:root:auto bandwidth for S8 very small or failed (h=0.00023767922725696238,N_eff=2127.3721251257216). Using fallback (h=0.009390146129003105)
# WARNING:root:auto bandwidth for w very small or failed (h=0.00026022364463334683,N_eff=1964.348428127311). Using fallback (h=0.021135205457521768)
# WARNING:root:auto bandwidth for wa very small or failed (h=0.00022189052348373228,N_eff=1963.738386997717). Using fallback (h=0.026253895535249858)
# WARNING:root:auto bandwidth for H0 very small or failed (h=0.00025362748507259676,N_eff=2017.44899246787). Using fallback (h=0.026324012701894817)
